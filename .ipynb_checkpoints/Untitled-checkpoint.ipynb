# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/covid_19_data.csv")

# %%
cases_by_location = df.groupby(['Province/State', 'Country/Region'])

# %%
data = {}
for name, location in cases_by_location:
    string = name[0]
    print(string)
    print(location.sum()["Deaths"])
    print(location.sum()["Confirmed"])
    print(location.sum()["Recovered"])
# Out:
#  Montreal, QC
# 0.0
# 17.0
# 0.0
#  Norfolk County, MA
# 0.0
# 7.0
# 0.0
# Alabama
# 0.0
# 52.0
# 0.0
# Alameda County, CA
# 0.0
# 6.0
# 0.0
# Alaska
# 0.0
# 3.0
# 0.0
# Alberta
# 0.0
# 205.0
# 0.0
# Anhui
# 209.0
# 40717.0
# 24801.0
# Arizona
# 0.0
# 82.0
# 7.0
# Arkansas
# 0.0
# 63.0
# 0.0
# Ashland, NE
# 0.0
# 11.0
# 0.0
# Australian Capital Territory
# 0.0
# 5.0
# 0.0
# Bavaria
# 0.0
# 17.0
# 0.0
# Beijing
# 226.0
# 17531.0
# 8282.0
# Bennington County, VT
# 0.0
# 1.0
# 0.0
# Bergen County, NJ
# 0.0
# 16.0
# 0.0
# Berkeley, CA
# 0.0
# 4.0
# 0.0
# Berkshire County, MA
# 0.0
# 2.0
# 0.0
# Boston, MA
# 0.0
# 34.0
# 7.0
# British Columbia
# 11.0
# 704.0
# 67.0
# Broward County, FL
# 0.0
# 7.0
# 0.0
# Calgary, Alberta
# 0.0
# 3.0
# 0.0
# California
# 31.0
# 2159.0
# 34.0
# Carver County, MN
# 0.0
# 1.0
# 0.0
# Cayman Islands
# 1.0
# 1.0
# 0.0
# Channel Islands
# 0.0
# 17.0
# 0.0
# Charleston County, SC
# 0.0
# 3.0
# 0.0
# Charlotte County, FL
# 0.0
# 1.0
# 0.0
# Chatham County, NC
# ...

# %%
for index, row in df.iterrows():
    row['location'] = ""
    row['location'] = str(row['Province/State']) + row['Country/Region'] 
#     print(row)

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0
